# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
os.getcwd()
# Out:
# '/Users/gbemidebe/Documents/GitHub/knnGuidedDesign/notebooks'

# %%
os.chdir("../")
os.getcwd()
# Out:
# '/Users/gbemidebe/Documents/GitHub/knnGuidedDesign'

# %%
from src.arch.model import *

# %%
model = VAE(input_dim=10, latent_dim=10)

# %%
model
# Out:
# (Sequential(
#    (0): Linear(in_features=10, out_features=100, bias=True)
#    (1): Tanh()
#    (2): Dropout(p=0.2, inplace=False)
#    (3): Linear(in_features=100, out_features=70, bias=True)
#    (4): Tanh()
#    (5): Dropout(p=0.2, inplace=False)
#    (6): Linear(in_features=70, out_features=20, bias=True)
#  ),
#  Sequential(
#    (0): Linear(in_features=10, out_features=40, bias=True)
#    (1): Tanh()
#    (2): Dropout(p=0.2, inplace=False)
#    (3): Linear(in_features=40, out_features=40, bias=True)
#    (4): Tanh()
#    (5): Dropout(p=0.2, inplace=False)
#    (6): Linear(in_features=40, out_features=10, bias=True)
#    (7): Sigmoid()
#  ))

# %%
len(model[0])
# Out:
# 7

# %%
list(range(0, 7, 3))
# Out:
# [0, 3, 6]

# %%
for i in range(0, len(model[0]), 3):
    # turn off grad
    model[0][i].weight.requires_grad = False
    # print weights
    print(f'Weight of {i} is \n{model[0][i].weight}')
# Out:
# Weight of 0 is
# Parameter containing:
# tensor([[ 1.5948e-01, -5.2435e-02, -3.1524e-01, -1.2156e-01,  1.7954e-01,
#          -1.1295e-01, -5.4530e-02, -1.2276e-01,  2.4427e-01,  5.9194e-02],
#         [ 5.4832e-02, -1.1855e-01, -2.0680e-01,  9.4376e-02,  2.6734e-01,
#           2.7136e-01,  4.3889e-03, -1.3040e-01,  2.9403e-01,  1.7456e-01],
#         [-1.2465e-01, -2.0035e-01, -2.8289e-01,  6.4553e-02,  4.7900e-02,
#          -3.1149e-01,  3.1966e-03,  2.1973e-01,  2.8131e-01,  5.8449e-02],
#         [-2.2555e-02, -4.9925e-02,  1.1397e-01, -9.0482e-02, -1.7699e-01,
#          -1.9026e-01,  1.8579e-01,  2.5469e-02,  1.1342e-02, -2.5382e-02],
#         [-1.5385e-01,  1.9916e-01, -1.7896e-01,  1.0327e-01,  9.8869e-02,
#           1.0088e-01,  1.5457e-01,  2.5446e-01,  2.4906e-02, -1.2692e-01],
#         [ 2.8103e-01,  9.6447e-02,  1.5436e-01, -1.5073e-01,  9.6668e-02,
#          -5.3761e-02, -2.2936e-02, -2.2077e-02, -2.9246e-01, -2.9740e-02],
# ...

# %%
for i in range(0, len(model[1]), 3):
    print(f'Decoder weight of {i} is \n{model[1][i].weight}')
# Out:
# Decoder weight of 0 is
# Parameter containing:
# tensor([[ 0.2835, -0.0039,  0.2236, -0.2450, -0.0921, -0.2646,  0.2144, -0.0690,
#          -0.1159,  0.0319],
#         [-0.1666,  0.1681, -0.2491, -0.0535,  0.0560,  0.0421, -0.1610, -0.2888,
#          -0.2845, -0.1261],
#         [-0.1354,  0.3083,  0.1785,  0.0834, -0.2969, -0.2169,  0.2763, -0.1302,
#           0.0766,  0.0075],
#         [ 0.3140,  0.0254,  0.1763, -0.0676,  0.1808, -0.1915, -0.2752, -0.0976,
#          -0.0342,  0.2159],
#         [-0.1747, -0.0578,  0.1229, -0.3028, -0.1148, -0.2301,  0.1946,  0.1897,
#          -0.0281, -0.0624],
#         [ 0.0294,  0.1318,  0.0041,  0.0826, -0.2865,  0.3153,  0.2352, -0.0055,
#           0.2057, -0.2883],
#         [-0.1315, -0.2393,  0.2154,  0.2298, -0.2473,  0.1437, -0.0626, -0.2285,
#          -0.2833, -0.1678],
#         [ 0.3065, -0.2203, -0.1029, -0.3007, -0.0993,  0.0281, -0.1379, -0.2970,
#          -0.0572, -0.0591],
# ...

# %%
# import trainer
from src.arch.trainer import BaseTrainer

# %%
Trainer = BaseTrainer(seed=42, split=0.3)

# %%
gnnmodel = Trainer.trainGNN(hidden_gcn_dim=128, hidden_fcn_dim= 128,
                 n_gcn_layers=3, n_fcn_layers= 3,
                 num_epochs=1000, learning_rate=1e-3, batch_size=16, data_path='./data/data.csv')
# Out:
# Seed set to 42
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /Users/gbemidebe/miniconda3/envs/MatML/lib/python3.8/site-packages/pytorch_lightning/trainer/setup.py:187: GPU available but not used. You can set it by doing `Trainer(accelerator='gpu')`.
# Missing logger folder: ../reports/GNNlogs_42/GNN
#
#   | Name      | Type    | Params
# --------------------------------------
# 0 | model     | GNN     | 92.3 K
# 1 | criterion | MSELoss | 0
# --------------------------------------
# 92.3 K    Trainable params
# 0         Non-trainable params
# 92.3 K    Total params
# 0.369     Total estimated model params size (MB)
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# ...
